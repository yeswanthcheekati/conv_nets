# %%
import numpy as np
from PIL import Image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
file = Image.open('cylinder/0.png')

# %%
file = file.convert('L')

# %%
file = np.array(file)+59

# %%
file[file<255] = 0

# %%
file.shape
# Out:
# (256, 256)

# %%
plt.imshow(ndimage.morphology.distance_transform_edt(file))
plt.colorbar()

# %%
file = Image.open('0.png')
file = file.convert('L')
file = np.array(file)+59
file[file<255] = 0

# %%
plt.imshow(ndimage.morphology.distance_transform_edt(file))
plt.colorbar()

# %%
file = Image.open('cylinder/label_20.png')

# %%
np.array(file).shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(np.array(file))

# %%
plt.imshow(np.array(file)[:,:,:])
plt.colorbar()

# %%
plt.imshow(np.array(file)[120:140,125:145,1])

# %%
file
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x110147B70>
