# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#input sample
img = Image.open('crop_data/cylinder/cylinder.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x128 at 0x10669DCC0>

# %%
#output sample at u = 34
img = Image.open('crop_data/cylinder/label_0.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x128 at 0x1066A0278>

# %%
#input sample
img = Image.open('crop_data/bike/bike.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x128 at 0x106752198>

# %%
#output sample at u = 34
img = Image.open('crop_data/bike/label_34.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x128 at 0x106752F28>

# %%
#input sample
img = Image.open('crop_data/sq_45/sq_45.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x128 at 0x10677ACF8>

# %%
#output sample at u = 34
img = Image.open('crop_data/sq_45/label_0.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x128 at 0x1067667B8>
